# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
        
    # TODO: Implement Function
    source_sentences = source_text.split('\n')
    target_sentences = target_text.split('\n')
    
    source_sentences_int = [[source_vocab_to_int[w] for w in s.split()] for s in source_sentences]
    target_sentences_int = [[target_vocab_to_int[w] for w in (s + ' <EOS>').split()] for s in target_sentences]
    
    return source_sentences_int, target_sentences_int

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    inputs = tf.placeholder(tf.int32, shape=[None,None], name='input')
    targets = tf.placeholder(tf.int32, shape=[None,None], name='targets')
    learning_rate = tf.placeholder(tf.float32, shape=[], name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, shape=[], name='keep_prob')
    target_sequence_length = tf.placeholder(tf.int32, shape=[None], name='target_sequence_length')
    max_target_sequence_length = tf.reduce_max(target_sequence_length, axis=0, name='max_target_sequence_length')
    source_sequence_length = tf.placeholder(tf.int32, shape=[None], name='source_sequence_length')
    
    return inputs, targets, learning_rate, keep_prob, target_sequence_length, \
           max_target_sequence_length, source_sequence_length
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    
    # TODO: Implement Function
    target_batch = tf.strided_slice(target_data, [0, 0], [batch_size, -1], strides=[1, 1])
    target_batch = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']) , target_batch], 1)
    return target_batch

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    #embeddings = tf.Variable(tf.random_uniform([source_vocab_size, encoding_embedding_size], -1.0, 1.0), name='embeddings')
    #embeddings = tf.Variable(tf.truncated_normal([source_vocab_size, encoding_embedding_size], stddev=encoding_embedding_size**-0.5), name='embeddings')
    #embedded_input = tf.nn.embedding_lookup(embeddings, rnn_inputs)

    embedded_input = tf.contrib.layers.embed_sequence(rnn_inputs, vocab_size=source_vocab_size, embed_dim=encoding_embedding_size)
    def lstm_cell():
        cell = tf.contrib.rnn.LSTMCell(rnn_size)
        return tf.contrib.rnn.DropoutWrapper(cell, output_keep_prob=keep_prob)
    
    stacked_lstm = tf.contrib.rnn.MultiRNNCell([lstm_cell() for _ in range(num_layers)])
    
    rnn_outputs, rnn_state = tf.nn.dynamic_rnn(stacked_lstm, embedded_input, source_sequence_length, dtype=tf.float32)
    
    return rnn_outputs, rnn_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    
    helper = tf.contrib.seq2seq.TrainingHelper(dec_embed_input, target_sequence_length)
    
    dec_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob=keep_prob)
    
    decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, helper, encoder_state, output_layer=output_layer)
    
    decoder_output, _ = tf.contrib.seq2seq.dynamic_decode(decoder, impute_finished=True, maximum_iterations=max_summary_length)

    return decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function

    #with tf.variable_scope(decoding_scope) as scope:
    
    #start_tokens = tf.fill([batch_size], start_of_sequence_id)
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], name='start_tokens')
    helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings, start_tokens, end_of_sequence_id)
    
    decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, helper, encoder_state, output_layer=output_layer)
    
    decoder_output, _ = tf.contrib.seq2seq.dynamic_decode(decoder, impute_finished=True, maximum_iterations=max_target_sequence_length)

    return decoder_output




"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
    def dec_lstm_cell():
        return tf.contrib.rnn.LSTMCell(rnn_size)
        #return tf.contrib.rnn.DropoutWrapper(cell, output_keep_prob=keep_prob) # only apply dropout in decoding_layer_train
    
    dec_stacked_lstm = tf.contrib.rnn.MultiRNNCell([dec_lstm_cell() for _ in range(num_layers)])
    
    #dec_rnn_outputs, dec_rnn_state = tf.nn.dynamic_rnn(dec_stacked_lstm, dec_embed_input, target_sequence_length, dtype=tf.float32)
    
    output_layer = Dense(target_vocab_size)#,kernel_initializer=
    # TODO: Implement Function
    
    with tf.variable_scope('decoding_layer') as decoding_scope:
        training_outputs = decoding_layer_train(encoder_state, 
                                                dec_stacked_lstm, 
                                                dec_embed_input, 
                                                target_sequence_length, 
                                                max_target_sequence_length, 
                                                output_layer, 
                                                keep_prob)
    
        decoding_scope.reuse_variables()
        inference_outputs = decoding_layer_infer(encoder_state, 
                                                 dec_stacked_lstm,
                                                 dec_embeddings,
                                                 target_vocab_to_int['<GO>'],
                                                 target_vocab_to_int['<EOS>'],
                                                 max_target_sequence_length,
                                                 target_vocab_size,
                                                 output_layer,
                                                 batch_size, 
                                                 keep_prob)
        
    return training_outputs, inference_outputs



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    
    
    _, enc_state = encoding_layer(input_data, rnn_size, num_layers, keep_prob,
                                  source_sequence_length, source_vocab_size, enc_embedding_size)
    dec_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    training_output, inference_output = decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length,
                                                       rnn_size, num_layers, target_vocab_to_int, target_vocab_size, 
                                                       batch_size, keep_prob, dec_embedding_size)
    
    return training_output, inference_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 5
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 512
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 200
decoding_embedding_size = 200
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.75
display_step = 10

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   10/1077 - Train Accuracy: 0.2919, Validation Accuracy: 0.3842, Loss: 3.4847
# Epoch   0 Batch   20/1077 - Train Accuracy: 0.3758, Validation Accuracy: 0.4276, Loss: 2.8014
# Epoch   0 Batch   30/1077 - Train Accuracy: 0.3887, Validation Accuracy: 0.4570, Loss: 2.5846
# Epoch   0 Batch   40/1077 - Train Accuracy: 0.4180, Validation Accuracy: 0.4737, Loss: 2.4419
# Epoch   0 Batch   50/1077 - Train Accuracy: 0.4156, Validation Accuracy: 0.4833, Loss: 2.3309
# Epoch   0 Batch   60/1077 - Train Accuracy: 0.4617, Validation Accuracy: 0.5021, Loss: 2.1552
# Epoch   0 Batch   70/1077 - Train Accuracy: 0.3795, Validation Accuracy: 0.4673, Loss: 2.1670
# Epoch   0 Batch   80/1077 - Train Accuracy: 0.3871, Validation Accuracy: 0.4425, Loss: 1.9008
# Epoch   0 Batch   90/1077 - Train Accuracy: 0.4059, Validation Accuracy: 0.4737, Loss: 1.8542
# Epoch   0 Batch  100/1077 - Train Accuracy: 0.4184, Validation Accuracy: 0.4783, Loss: 1.6203
# Epoch   0 Batch  110/1077 - Train Accuracy: 0.4082, Validation Accuracy: 0.4467, Loss: 1.4674
# Epoch   0 Batch  120/1077 - Train Accuracy: 0.3863, Validation Accuracy: 0.4645, Loss: 1.4265
# Epoch   0 Batch  130/1077 - Train Accuracy: 0.4126, Validation Accuracy: 0.4613, Loss: 1.2320
# Epoch   0 Batch  140/1077 - Train Accuracy: 0.3688, Validation Accuracy: 0.4638, Loss: 1.3206
# Epoch   0 Batch  150/1077 - Train Accuracy: 0.4810, Validation Accuracy: 0.4936, Loss: 1.1281
# Epoch   0 Batch  160/1077 - Train Accuracy: 0.4820, Validation Accuracy: 0.5210, Loss: 1.0935
# Epoch   0 Batch  170/1077 - Train Accuracy: 0.4207, Validation Accuracy: 0.4979, Loss: 1.0731
# Epoch   0 Batch  180/1077 - Train Accuracy: 0.5016, Validation Accuracy: 0.5312, Loss: 1.0132
# Epoch   0 Batch  190/1077 - Train Accuracy: 0.5082, Validation Accuracy: 0.5241, Loss: 0.9560
# Epoch   0 Batch  200/1077 - Train Accuracy: 0.4566, Validation Accuracy: 0.5391, Loss: 0.9692
# Epoch   0 Batch  210/1077 - Train Accuracy: 0.5000, Validation Accuracy: 0.5408, Loss: 0.9092
# Epoch   0 Batch  220/1077 - Train Accuracy: 0.4799, Validation Accuracy: 0.5348, Loss: 0.8908
# Epoch   0 Batch  230/1077 - Train Accuracy: 0.5257, Validation Accuracy: 0.5380, Loss: 0.8384
# Epoch   0 Batch  240/1077 - Train Accuracy: 0.4914, Validation Accuracy: 0.5487, Loss: 0.8487
# Epoch   0 Batch  250/1077 - Train Accuracy: 0.5092, Validation Accuracy: 0.5458, Loss: 0.7660
# Epoch   0 Batch  260/1077 - Train Accuracy: 0.5089, Validation Accuracy: 0.5344, Loss: 0.7534
# Epoch   0 Batch  270/1077 - Train Accuracy: 0.5270, Validation Accuracy: 0.5504, Loss: 0.8059
# Epoch   0 Batch  280/1077 - Train Accuracy: 0.5652, Validation Accuracy: 0.5575, Loss: 0.7852
# Epoch   0 Batch  290/1077 - Train Accuracy: 0.5324, Validation Accuracy: 0.5820, Loss: 0.7788
# Epoch   0 Batch  300/1077 - Train Accuracy: 0.5271, Validation Accuracy: 0.5714, Loss: 0.7611
# Epoch   0 Batch  310/1077 - Train Accuracy: 0.5473, Validation Accuracy: 0.5952, Loss: 0.7504
# Epoch   0 Batch  320/1077 - Train Accuracy: 0.5715, Validation Accuracy: 0.5462, Loss: 0.6989
# Epoch   0 Batch  330/1077 - Train Accuracy: 0.5938, Validation Accuracy: 0.5916, Loss: 0.6905
# Epoch   0 Batch  340/1077 - Train Accuracy: 0.5226, Validation Accuracy: 0.5785, Loss: 0.7190
# Epoch   0 Batch  350/1077 - Train Accuracy: 0.5660, Validation Accuracy: 0.5522, Loss: 0.7181
# Epoch   0 Batch  360/1077 - Train Accuracy: 0.5602, Validation Accuracy: 0.5813, Loss: 0.6829
# Epoch   0 Batch  370/1077 - Train Accuracy: 0.5822, Validation Accuracy: 0.5639, Loss: 0.6421
# Epoch   0 Batch  380/1077 - Train Accuracy: 0.5723, Validation Accuracy: 0.5835, Loss: 0.6628
# Epoch   0 Batch  390/1077 - Train Accuracy: 0.5461, Validation Accuracy: 0.5881, Loss: 0.6895
# Epoch   0 Batch  400/1077 - Train Accuracy: 0.5820, Validation Accuracy: 0.5913, Loss: 0.6619
# Epoch   0 Batch  410/1077 - Train Accuracy: 0.5378, Validation Accuracy: 0.5902, Loss: 0.6765
# Epoch   0 Batch  420/1077 - Train Accuracy: 0.5516, Validation Accuracy: 0.5632, Loss: 0.6294
# Epoch   0 Batch  430/1077 - Train Accuracy: 0.5813, Validation Accuracy: 0.6119, Loss: 0.6416
# Epoch   0 Batch  440/1077 - Train Accuracy: 0.5711, Validation Accuracy: 0.6151, Loss: 0.6661
# Epoch   0 Batch  450/1077 - Train Accuracy: 0.5809, Validation Accuracy: 0.5923, Loss: 0.5942
# Epoch   0 Batch  460/1077 - Train Accuracy: 0.5887, Validation Accuracy: 0.6001, Loss: 0.6531
# Epoch   0 Batch  470/1077 - Train Accuracy: 0.5567, Validation Accuracy: 0.6257, Loss: 0.6348
# Epoch   0 Batch  480/1077 - Train Accuracy: 0.6106, Validation Accuracy: 0.6172, Loss: 0.6014
# Epoch   0 Batch  490/1077 - Train Accuracy: 0.6020, Validation Accuracy: 0.5927, Loss: 0.5964
# Epoch   0 Batch  500/1077 - Train Accuracy: 0.5941, Validation Accuracy: 0.6129, Loss: 0.5684
# Epoch   0 Batch  510/1077 - Train Accuracy: 0.6070, Validation Accuracy: 0.6168, Loss: 0.5666
# Epoch   0 Batch  520/1077 - Train Accuracy: 0.6704, Validation Accuracy: 0.6392, Loss: 0.5343
# Epoch   0 Batch  530/1077 - Train Accuracy: 0.6051, Validation Accuracy: 0.6254, Loss: 0.5939
# Epoch   0 Batch  540/1077 - Train Accuracy: 0.6246, Validation Accuracy: 0.6342, Loss: 0.5190
# Epoch   0 Batch  550/1077 - Train Accuracy: 0.5930, Validation Accuracy: 0.6523, Loss: 0.5767
# Epoch   0 Batch  560/1077 - Train Accuracy: 0.6020, Validation Accuracy: 0.6367, Loss: 0.5242
# Epoch   0 Batch  570/1077 - Train Accuracy: 0.6197, Validation Accuracy: 0.6310, Loss: 0.5713
# Epoch   0 Batch  580/1077 - Train Accuracy: 0.6618, Validation Accuracy: 0.6470, Loss: 0.4911
# Epoch   0 Batch  590/1077 - Train Accuracy: 0.5942, Validation Accuracy: 0.6051, Loss: 0.5595
# Epoch   0 Batch  600/1077 - Train Accuracy: 0.6719, Validation Accuracy: 0.6296, Loss: 0.4849
# Epoch   0 Batch  610/1077 - Train Accuracy: 0.6340, Validation Accuracy: 0.6566, Loss: 0.5352
# Epoch   0 Batch  620/1077 - Train Accuracy: 0.6332, Validation Accuracy: 0.6605, Loss: 0.4996
# Epoch   0 Batch  630/1077 - Train Accuracy: 0.6531, Validation Accuracy: 0.6527, Loss: 0.5029
# Epoch   0 Batch  640/1077 - Train Accuracy: 0.6451, Validation Accuracy: 0.6602, Loss: 0.4902
# Epoch   0 Batch  650/1077 - Train Accuracy: 0.5961, Validation Accuracy: 0.6357, Loss: 0.5204
# Epoch   0 Batch  660/1077 - Train Accuracy: 0.6469, Validation Accuracy: 0.6484, Loss: 0.5106
# Epoch   0 Batch  670/1077 - Train Accuracy: 0.6779, Validation Accuracy: 0.6612, Loss: 0.4652
# Epoch   0 Batch  680/1077 - Train Accuracy: 0.6231, Validation Accuracy: 0.6268, Loss: 0.4876
# Epoch   0 Batch  690/1077 - Train Accuracy: 0.6633, Validation Accuracy: 0.6495, Loss: 0.4780
# Epoch   0 Batch  700/1077 - Train Accuracy: 0.5992, Validation Accuracy: 0.6449, Loss: 0.4855
# Epoch   0 Batch  710/1077 - Train Accuracy: 0.6141, Validation Accuracy: 0.6559, Loss: 0.4839
# Epoch   0 Batch  720/1077 - Train Accuracy: 0.6287, Validation Accuracy: 0.6634, Loss: 0.5497
# Epoch   0 Batch  730/1077 - Train Accuracy: 0.5953, Validation Accuracy: 0.6392, Loss: 0.5093
# Epoch   0 Batch  740/1077 - Train Accuracy: 0.6633, Validation Accuracy: 0.6719, Loss: 0.4846
# Epoch   0 Batch  750/1077 - Train Accuracy: 0.6777, Validation Accuracy: 0.6619, Loss: 0.4746
# Epoch   0 Batch  760/1077 - Train Accuracy: 0.6711, Validation Accuracy: 0.6594, Loss: 0.4597
# Epoch   0 Batch  770/1077 - Train Accuracy: 0.6678, Validation Accuracy: 0.6612, Loss: 0.4200
# Epoch   0 Batch  780/1077 - Train Accuracy: 0.6949, Validation Accuracy: 0.6673, Loss: 0.4446
# Epoch   0 Batch  790/1077 - Train Accuracy: 0.5980, Validation Accuracy: 0.6371, Loss: 0.4813
# Epoch   0 Batch  800/1077 - Train Accuracy: 0.6508, Validation Accuracy: 0.6705, Loss: 0.4442
# Epoch   0 Batch  810/1077 - Train Accuracy: 0.6812, Validation Accuracy: 0.6722, Loss: 0.4136
# Epoch   0 Batch  820/1077 - Train Accuracy: 0.6605, Validation Accuracy: 0.6911, Loss: 0.4598
# Epoch   0 Batch  830/1077 - Train Accuracy: 0.6707, Validation Accuracy: 0.6861, Loss: 0.4299
# Epoch   0 Batch  840/1077 - Train Accuracy: 0.6863, Validation Accuracy: 0.6623, Loss: 0.3982
# Epoch   0 Batch  850/1077 - Train Accuracy: 0.6510, Validation Accuracy: 0.6900, Loss: 0.4442
# Epoch   0 Batch  860/1077 - Train Accuracy: 0.6908, Validation Accuracy: 0.6751, Loss: 0.3996
# Epoch   0 Batch  870/1077 - Train Accuracy: 0.6521, Validation Accuracy: 0.6992, Loss: 0.4063
# Epoch   0 Batch  880/1077 - Train Accuracy: 0.7305, Validation Accuracy: 0.7013, Loss: 0.3694
# Epoch   0 Batch  890/1077 - Train Accuracy: 0.7653, Validation Accuracy: 0.6836, Loss: 0.3503
# Epoch   0 Batch  900/1077 - Train Accuracy: 0.7297, Validation Accuracy: 0.7067, Loss: 0.3677
# Epoch   0 Batch  910/1077 - Train Accuracy: 0.7158, Validation Accuracy: 0.6879, Loss: 0.3443
# Epoch   0 Batch  920/1077 - Train Accuracy: 0.7480, Validation Accuracy: 0.7305, Loss: 0.3467
# Epoch   0 Batch  930/1077 - Train Accuracy: 0.7430, Validation Accuracy: 0.7102, Loss: 0.3194
# Epoch   0 Batch  940/1077 - Train Accuracy: 0.7309, Validation Accuracy: 0.7276, Loss: 0.3264
# Epoch   0 Batch  950/1077 - Train Accuracy: 0.7161, Validation Accuracy: 0.6658, Loss: 0.3039
# Epoch   0 Batch  960/1077 - Train Accuracy: 0.7474, Validation Accuracy: 0.7234, Loss: 0.3058
# Epoch   0 Batch  970/1077 - Train Accuracy: 0.7926, Validation Accuracy: 0.7031, Loss: 0.3094
# Epoch   0 Batch  980/1077 - Train Accuracy: 0.7539, Validation Accuracy: 0.7585, Loss: 0.3072
# Epoch   0 Batch  990/1077 - Train Accuracy: 0.7253, Validation Accuracy: 0.7553, Loss: 0.3053
# Epoch   0 Batch 1000/1077 - Train Accuracy: 0.7801, Validation Accuracy: 0.7543, Loss: 0.2492
# Epoch   0 Batch 1010/1077 - Train Accuracy: 0.7562, Validation Accuracy: 0.7251, Loss: 0.2747
# Epoch   0 Batch 1020/1077 - Train Accuracy: 0.8137, Validation Accuracy: 0.7518, Loss: 0.2580
# Epoch   0 Batch 1030/1077 - Train Accuracy: 0.7652, Validation Accuracy: 0.7667, Loss: 0.2762
# Epoch   0 Batch 1040/1077 - Train Accuracy: 0.7948, Validation Accuracy: 0.7791, Loss: 0.2706
# Epoch   0 Batch 1050/1077 - Train Accuracy: 0.7594, Validation Accuracy: 0.7766, Loss: 0.2481
# Epoch   0 Batch 1060/1077 - Train Accuracy: 0.7836, Validation Accuracy: 0.7166, Loss: 0.2244
# Epoch   0 Batch 1070/1077 - Train Accuracy: 0.7688, Validation Accuracy: 0.7731, Loss: 0.2476
# Epoch   1 Batch   10/1077 - Train Accuracy: 0.7887, Validation Accuracy: 0.7713, Loss: 0.2492
# Epoch   1 Batch   20/1077 - Train Accuracy: 0.7746, Validation Accuracy: 0.7710, Loss: 0.2211
# Epoch   1 Batch   30/1077 - Train Accuracy: 0.8199, Validation Accuracy: 0.8121, Loss: 0.2241
# Epoch   1 Batch   40/1077 - Train Accuracy: 0.8387, Validation Accuracy: 0.7773, Loss: 0.2038
# Epoch   1 Batch   50/1077 - Train Accuracy: 0.8492, Validation Accuracy: 0.7766, Loss: 0.2075
# Epoch   1 Batch   60/1077 - Train Accuracy: 0.8266, Validation Accuracy: 0.8058, Loss: 0.1966
# Epoch   1 Batch   70/1077 - Train Accuracy: 0.8458, Validation Accuracy: 0.8224, Loss: 0.2033
# Epoch   1 Batch   80/1077 - Train Accuracy: 0.8137, Validation Accuracy: 0.7869, Loss: 0.2022
# Epoch   1 Batch   90/1077 - Train Accuracy: 0.8230, Validation Accuracy: 0.8011, Loss: 0.1972
# Epoch   1 Batch  100/1077 - Train Accuracy: 0.8578, Validation Accuracy: 0.8430, Loss: 0.1723
# Epoch   1 Batch  110/1077 - Train Accuracy: 0.8773, Validation Accuracy: 0.8338, Loss: 0.1614
# Epoch   1 Batch  120/1077 - Train Accuracy: 0.8379, Validation Accuracy: 0.8033, Loss: 0.1874
# Epoch   1 Batch  130/1077 - Train Accuracy: 0.8553, Validation Accuracy: 0.8157, Loss: 0.1551
# Epoch   1 Batch  140/1077 - Train Accuracy: 0.8627, Validation Accuracy: 0.8040, Loss: 0.1547
# Epoch   1 Batch  150/1077 - Train Accuracy: 0.8687, Validation Accuracy: 0.8239, Loss: 0.1619
# Epoch   1 Batch  160/1077 - Train Accuracy: 0.8695, Validation Accuracy: 0.8487, Loss: 0.1593
# Epoch   1 Batch  170/1077 - Train Accuracy: 0.8402, Validation Accuracy: 0.8242, Loss: 0.1462
# Epoch   1 Batch  180/1077 - Train Accuracy: 0.8348, Validation Accuracy: 0.8320, Loss: 0.1574
# Epoch   1 Batch  190/1077 - Train Accuracy: 0.8879, Validation Accuracy: 0.8469, Loss: 0.1336
# Epoch   1 Batch  200/1077 - Train Accuracy: 0.8648, Validation Accuracy: 0.8445, Loss: 0.1653
# Epoch   1 Batch  210/1077 - Train Accuracy: 0.8564, Validation Accuracy: 0.8139, Loss: 0.1483
# Epoch   1 Batch  220/1077 - Train Accuracy: 0.8853, Validation Accuracy: 0.8359, Loss: 0.1409
# Epoch   1 Batch  230/1077 - Train Accuracy: 0.8620, Validation Accuracy: 0.8338, Loss: 0.1290
# Epoch   1 Batch  240/1077 - Train Accuracy: 0.8887, Validation Accuracy: 0.8629, Loss: 0.1280
# Epoch   1 Batch  250/1077 - Train Accuracy: 0.8920, Validation Accuracy: 0.8480, Loss: 0.1205
# Epoch   1 Batch  260/1077 - Train Accuracy: 0.9126, Validation Accuracy: 0.8509, Loss: 0.1164
# Epoch   1 Batch  270/1077 - Train Accuracy: 0.8633, Validation Accuracy: 0.8622, Loss: 0.1327
# Epoch   1 Batch  280/1077 - Train Accuracy: 0.8668, Validation Accuracy: 0.8555, Loss: 0.1361
# Epoch   1 Batch  290/1077 - Train Accuracy: 0.8543, Validation Accuracy: 0.8580, Loss: 0.1396
# Epoch   1 Batch  300/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.8583, Loss: 0.1051
# Epoch   1 Batch  310/1077 - Train Accuracy: 0.8781, Validation Accuracy: 0.8473, Loss: 0.1209
# Epoch   1 Batch  320/1077 - Train Accuracy: 0.8773, Validation Accuracy: 0.8505, Loss: 0.1128
# Epoch   1 Batch  330/1077 - Train Accuracy: 0.9121, Validation Accuracy: 0.8384, Loss: 0.1095
# Epoch   1 Batch  340/1077 - Train Accuracy: 0.9112, Validation Accuracy: 0.8626, Loss: 0.1103
# Epoch   1 Batch  350/1077 - Train Accuracy: 0.8680, Validation Accuracy: 0.8622, Loss: 0.1053
# Epoch   1 Batch  360/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.8732, Loss: 0.0951
# Epoch   1 Batch  370/1077 - Train Accuracy: 0.9129, Validation Accuracy: 0.8743, Loss: 0.0984
# Epoch   1 Batch  380/1077 - Train Accuracy: 0.9113, Validation Accuracy: 0.8686, Loss: 0.0893
# Epoch   1 Batch  390/1077 - Train Accuracy: 0.8918, Validation Accuracy: 0.8782, Loss: 0.1103
# Epoch   1 Batch  400/1077 - Train Accuracy: 0.8895, Validation Accuracy: 0.8739, Loss: 0.0966
# Epoch   1 Batch  410/1077 - Train Accuracy: 0.8840, Validation Accuracy: 0.8707, Loss: 0.1056
# Epoch   1 Batch  420/1077 - Train Accuracy: 0.9285, Validation Accuracy: 0.8725, Loss: 0.0746
# Epoch   1 Batch  430/1077 - Train Accuracy: 0.9113, Validation Accuracy: 0.8984, Loss: 0.0869
# Epoch   1 Batch  440/1077 - Train Accuracy: 0.8820, Validation Accuracy: 0.8732, Loss: 0.1082
# Epoch   1 Batch  450/1077 - Train Accuracy: 0.8992, Validation Accuracy: 0.8626, Loss: 0.0946
# Epoch   1 Batch  460/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.8729, Loss: 0.0783
# Epoch   1 Batch  470/1077 - Train Accuracy: 0.9354, Validation Accuracy: 0.8739, Loss: 0.0780
# Epoch   1 Batch  480/1077 - Train Accuracy: 0.9194, Validation Accuracy: 0.8917, Loss: 0.0673
# Epoch   1 Batch  490/1077 - Train Accuracy: 0.8984, Validation Accuracy: 0.8796, Loss: 0.0846
# Epoch   1 Batch  500/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.8768, Loss: 0.0523
# Epoch   1 Batch  510/1077 - Train Accuracy: 0.9172, Validation Accuracy: 0.8938, Loss: 0.0703
# Epoch   1 Batch  520/1077 - Train Accuracy: 0.9509, Validation Accuracy: 0.9119, Loss: 0.0574
# Epoch   1 Batch  530/1077 - Train Accuracy: 0.8727, Validation Accuracy: 0.8771, Loss: 0.0710
# Epoch   1 Batch  540/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.8846, Loss: 0.0598
# Epoch   1 Batch  550/1077 - Train Accuracy: 0.8480, Validation Accuracy: 0.8828, Loss: 0.0710
# Epoch   1 Batch  560/1077 - Train Accuracy: 0.9082, Validation Accuracy: 0.8881, Loss: 0.0637
# Epoch   1 Batch  570/1077 - Train Accuracy: 0.9128, Validation Accuracy: 0.8842, Loss: 0.0651
# Epoch   1 Batch  580/1077 - Train Accuracy: 0.9267, Validation Accuracy: 0.9013, Loss: 0.0524
# Epoch   1 Batch  590/1077 - Train Accuracy: 0.9038, Validation Accuracy: 0.9080, Loss: 0.0669
# Epoch   1 Batch  600/1077 - Train Accuracy: 0.9483, Validation Accuracy: 0.8888, Loss: 0.0592
# Epoch   1 Batch  610/1077 - Train Accuracy: 0.9400, Validation Accuracy: 0.9183, Loss: 0.0648
# Epoch   1 Batch  620/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9251, Loss: 0.0560
# Epoch   1 Batch  630/1077 - Train Accuracy: 0.9387, Validation Accuracy: 0.9165, Loss: 0.0532
# Epoch   1 Batch  640/1077 - Train Accuracy: 0.9222, Validation Accuracy: 0.8974, Loss: 0.0519
# Epoch   1 Batch  650/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.9027, Loss: 0.0511
# Epoch   1 Batch  660/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9141, Loss: 0.0510
# Epoch   1 Batch  670/1077 - Train Accuracy: 0.9368, Validation Accuracy: 0.9226, Loss: 0.0579
# Epoch   1 Batch  680/1077 - Train Accuracy: 0.9100, Validation Accuracy: 0.8970, Loss: 0.0583
# Epoch   1 Batch  690/1077 - Train Accuracy: 0.9266, Validation Accuracy: 0.8984, Loss: 0.0569
# Epoch   1 Batch  700/1077 - Train Accuracy: 0.9195, Validation Accuracy: 0.9180, Loss: 0.0463
# Epoch   1 Batch  710/1077 - Train Accuracy: 0.9242, Validation Accuracy: 0.9070, Loss: 0.0411
# Epoch   1 Batch  720/1077 - Train Accuracy: 0.9128, Validation Accuracy: 0.8956, Loss: 0.0636
# Epoch   1 Batch  730/1077 - Train Accuracy: 0.9301, Validation Accuracy: 0.8842, Loss: 0.0616
# Epoch   1 Batch  740/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.8938, Loss: 0.0451
# Epoch   1 Batch  750/1077 - Train Accuracy: 0.9148, Validation Accuracy: 0.8949, Loss: 0.0459
# Epoch   1 Batch  760/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.9141, Loss: 0.0516
# Epoch   1 Batch  770/1077 - Train Accuracy: 0.9215, Validation Accuracy: 0.9254, Loss: 0.0472
# Epoch   1 Batch  780/1077 - Train Accuracy: 0.9070, Validation Accuracy: 0.9105, Loss: 0.0650
# Epoch   1 Batch  790/1077 - Train Accuracy: 0.9203, Validation Accuracy: 0.9258, Loss: 0.0505
# Epoch   1 Batch  800/1077 - Train Accuracy: 0.9203, Validation Accuracy: 0.9403, Loss: 0.0512
# Epoch   1 Batch  810/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9119, Loss: 0.0398
# Epoch   1 Batch  820/1077 - Train Accuracy: 0.8965, Validation Accuracy: 0.9197, Loss: 0.0484
# Epoch   1 Batch  830/1077 - Train Accuracy: 0.8824, Validation Accuracy: 0.9293, Loss: 0.0609
# Epoch   1 Batch  840/1077 - Train Accuracy: 0.9473, Validation Accuracy: 0.9339, Loss: 0.0456
# Epoch   1 Batch  850/1077 - Train Accuracy: 0.9126, Validation Accuracy: 0.9268, Loss: 0.0711
# Epoch   1 Batch  860/1077 - Train Accuracy: 0.9401, Validation Accuracy: 0.9123, Loss: 0.0514
# Epoch   1 Batch  870/1077 - Train Accuracy: 0.8865, Validation Accuracy: 0.9233, Loss: 0.0534
# Epoch   1 Batch  880/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9165, Loss: 0.0572
# Epoch   1 Batch  890/1077 - Train Accuracy: 0.9401, Validation Accuracy: 0.9098, Loss: 0.0473
# Epoch   1 Batch  900/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9215, Loss: 0.0485
# Epoch   1 Batch  910/1077 - Train Accuracy: 0.9185, Validation Accuracy: 0.9087, Loss: 0.0489
# Epoch   1 Batch  920/1077 - Train Accuracy: 0.9359, Validation Accuracy: 0.9258, Loss: 0.0439
# Epoch   1 Batch  930/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9055, Loss: 0.0433
# Epoch   1 Batch  940/1077 - Train Accuracy: 0.9563, Validation Accuracy: 0.9219, Loss: 0.0367
# Epoch   1 Batch  950/1077 - Train Accuracy: 0.9379, Validation Accuracy: 0.9119, Loss: 0.0366
# Epoch   1 Batch  960/1077 - Train Accuracy: 0.9513, Validation Accuracy: 0.9116, Loss: 0.0400
# Epoch   1 Batch  970/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9055, Loss: 0.0409
# Epoch   1 Batch  980/1077 - Train Accuracy: 0.9129, Validation Accuracy: 0.9183, Loss: 0.0443
# Epoch   1 Batch  990/1077 - Train Accuracy: 0.9424, Validation Accuracy: 0.9279, Loss: 0.0460
# Epoch   1 Batch 1000/1077 - Train Accuracy: 0.9453, Validation Accuracy: 0.9205, Loss: 0.0417
# Epoch   1 Batch 1010/1077 - Train Accuracy: 0.9566, Validation Accuracy: 0.9276, Loss: 0.0400
# Epoch   1 Batch 1020/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9187, Loss: 0.0304
# Epoch   1 Batch 1030/1077 - Train Accuracy: 0.9398, Validation Accuracy: 0.9197, Loss: 0.0423
# Epoch   1 Batch 1040/1077 - Train Accuracy: 0.9428, Validation Accuracy: 0.9137, Loss: 0.0416
# Epoch   1 Batch 1050/1077 - Train Accuracy: 0.9574, Validation Accuracy: 0.9336, Loss: 0.0334
# Epoch   1 Batch 1060/1077 - Train Accuracy: 0.9602, Validation Accuracy: 0.9375, Loss: 0.0354
# Epoch   1 Batch 1070/1077 - Train Accuracy: 0.9551, Validation Accuracy: 0.9293, Loss: 0.0364
# Epoch   2 Batch   10/1077 - Train Accuracy: 0.9334, Validation Accuracy: 0.9336, Loss: 0.0467
# Epoch   2 Batch   20/1077 - Train Accuracy: 0.9691, Validation Accuracy: 0.9304, Loss: 0.0311
# Epoch   2 Batch   30/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9389, Loss: 0.0365
# Epoch   2 Batch   40/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9205, Loss: 0.0278
# Epoch   2 Batch   50/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9212, Loss: 0.0358
# Epoch   2 Batch   60/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9240, Loss: 0.0348
# Epoch   2 Batch   70/1077 - Train Accuracy: 0.9396, Validation Accuracy: 0.9311, Loss: 0.0457
# Epoch   2 Batch   80/1077 - Train Accuracy: 0.9512, Validation Accuracy: 0.9197, Loss: 0.0327
# Epoch   2 Batch   90/1077 - Train Accuracy: 0.9563, Validation Accuracy: 0.9251, Loss: 0.0380
# Epoch   2 Batch  100/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9187, Loss: 0.0333
# Epoch   2 Batch  110/1077 - Train Accuracy: 0.9738, Validation Accuracy: 0.9396, Loss: 0.0275
# Epoch   2 Batch  120/1077 - Train Accuracy: 0.9582, Validation Accuracy: 0.9364, Loss: 0.0348
# Epoch   2 Batch  130/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9240, Loss: 0.0325
# Epoch   2 Batch  140/1077 - Train Accuracy: 0.9576, Validation Accuracy: 0.9094, Loss: 0.0309
# Epoch   2 Batch  150/1077 - Train Accuracy: 0.9554, Validation Accuracy: 0.9435, Loss: 0.0352
# Epoch   2 Batch  160/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9368, Loss: 0.0238
# Epoch   2 Batch  170/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9354, Loss: 0.0384
# Epoch   2 Batch  180/1077 - Train Accuracy: 0.9746, Validation Accuracy: 0.9421, Loss: 0.0302
# Epoch   2 Batch  190/1077 - Train Accuracy: 0.9590, Validation Accuracy: 0.9237, Loss: 0.0268
# Epoch   2 Batch  200/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9336, Loss: 0.0401
# Epoch   2 Batch  210/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9300, Loss: 0.0409
# Epoch   2 Batch  220/1077 - Train Accuracy: 0.9601, Validation Accuracy: 0.9528, Loss: 0.0406
# Epoch   2 Batch  230/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9226, Loss: 0.0316
# Epoch   2 Batch  240/1077 - Train Accuracy: 0.9707, Validation Accuracy: 0.9368, Loss: 0.0261
# Epoch   2 Batch  250/1077 - Train Accuracy: 0.9499, Validation Accuracy: 0.9361, Loss: 0.0357
# Epoch   2 Batch  260/1077 - Train Accuracy: 0.9606, Validation Accuracy: 0.9251, Loss: 0.0269
# Epoch   2 Batch  270/1077 - Train Accuracy: 0.9313, Validation Accuracy: 0.9403, Loss: 0.0438
# Epoch   2 Batch  280/1077 - Train Accuracy: 0.9246, Validation Accuracy: 0.9386, Loss: 0.0396
# Epoch   2 Batch  290/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9268, Loss: 0.0449
# Epoch   2 Batch  300/1077 - Train Accuracy: 0.9650, Validation Accuracy: 0.9364, Loss: 0.0280
# Epoch   2 Batch  310/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9226, Loss: 0.0320
# Epoch   2 Batch  320/1077 - Train Accuracy: 0.9648, Validation Accuracy: 0.9272, Loss: 0.0400
# Epoch   2 Batch  330/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.9325, Loss: 0.0391
# Epoch   2 Batch  340/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9368, Loss: 0.0324
# Epoch   2 Batch  350/1077 - Train Accuracy: 0.9469, Validation Accuracy: 0.9208, Loss: 0.0330
# Epoch   2 Batch  360/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9460, Loss: 0.0223
# Epoch   2 Batch  370/1077 - Train Accuracy: 0.9587, Validation Accuracy: 0.9155, Loss: 0.0368
# Epoch   2 Batch  380/1077 - Train Accuracy: 0.9711, Validation Accuracy: 0.9521, Loss: 0.0280
# Epoch   2 Batch  390/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9357, Loss: 0.0384
# Epoch   2 Batch  400/1077 - Train Accuracy: 0.9430, Validation Accuracy: 0.9272, Loss: 0.0390
# Epoch   2 Batch  410/1077 - Train Accuracy: 0.9317, Validation Accuracy: 0.9357, Loss: 0.0453
# Epoch   2 Batch  420/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9570, Loss: 0.0227
# Epoch   2 Batch  430/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9389, Loss: 0.0334
# Epoch   2 Batch  440/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.9350, Loss: 0.0385
# Epoch   2 Batch  450/1077 - Train Accuracy: 0.9668, Validation Accuracy: 0.9190, Loss: 0.0381
# Epoch   2 Batch  460/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.9300, Loss: 0.0392
# Epoch   2 Batch  470/1077 - Train Accuracy: 0.9552, Validation Accuracy: 0.9350, Loss: 0.0306
# Epoch   2 Batch  480/1077 - Train Accuracy: 0.9683, Validation Accuracy: 0.9357, Loss: 0.0274
# Epoch   2 Batch  490/1077 - Train Accuracy: 0.9547, Validation Accuracy: 0.9226, Loss: 0.0301
# Epoch   2 Batch  500/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9432, Loss: 0.0263
# Epoch   2 Batch  510/1077 - Train Accuracy: 0.9508, Validation Accuracy: 0.9325, Loss: 0.0307
# Epoch   2 Batch  520/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9300, Loss: 0.0242
# Epoch   2 Batch  530/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9453, Loss: 0.0360
# Epoch   2 Batch  540/1077 - Train Accuracy: 0.9625, Validation Accuracy: 0.9492, Loss: 0.0208
# Epoch   2 Batch  550/1077 - Train Accuracy: 0.9266, Validation Accuracy: 0.9450, Loss: 0.0287
# Epoch   2 Batch  560/1077 - Train Accuracy: 0.9324, Validation Accuracy: 0.9474, Loss: 0.0279
# Epoch   2 Batch  570/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9336, Loss: 0.0356
# Epoch   2 Batch  580/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9506, Loss: 0.0221
# Epoch   2 Batch  590/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.9457, Loss: 0.0325
# Epoch   2 Batch  600/1077 - Train Accuracy: 0.9725, Validation Accuracy: 0.9545, Loss: 0.0327
# Epoch   2 Batch  610/1077 - Train Accuracy: 0.9581, Validation Accuracy: 0.9503, Loss: 0.0345
# Epoch   2 Batch  620/1077 - Train Accuracy: 0.9633, Validation Accuracy: 0.9634, Loss: 0.0285
# Epoch   2 Batch  630/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9645, Loss: 0.0281
# Epoch   2 Batch  640/1077 - Train Accuracy: 0.9587, Validation Accuracy: 0.9609, Loss: 0.0246
# Epoch   2 Batch  650/1077 - Train Accuracy: 0.9852, Validation Accuracy: 0.9503, Loss: 0.0230
# Epoch   2 Batch  660/1077 - Train Accuracy: 0.9723, Validation Accuracy: 0.9439, Loss: 0.0215
# Epoch   2 Batch  670/1077 - Train Accuracy: 0.9624, Validation Accuracy: 0.9574, Loss: 0.0305
# Epoch   2 Batch  680/1077 - Train Accuracy: 0.9565, Validation Accuracy: 0.9510, Loss: 0.0275
# Epoch   2 Batch  690/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9407, Loss: 0.0337
# Epoch   2 Batch  700/1077 - Train Accuracy: 0.9629, Validation Accuracy: 0.9513, Loss: 0.0238
# Epoch   2 Batch  710/1077 - Train Accuracy: 0.9750, Validation Accuracy: 0.9545, Loss: 0.0233
# Epoch   2 Batch  720/1077 - Train Accuracy: 0.9498, Validation Accuracy: 0.9506, Loss: 0.0299
# Epoch   2 Batch  730/1077 - Train Accuracy: 0.9602, Validation Accuracy: 0.9574, Loss: 0.0347
# Epoch   2 Batch  740/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9506, Loss: 0.0261
# Epoch   2 Batch  750/1077 - Train Accuracy: 0.9590, Validation Accuracy: 0.9439, Loss: 0.0261
# Epoch   2 Batch  760/1077 - Train Accuracy: 0.9551, Validation Accuracy: 0.9577, Loss: 0.0334
# Epoch   2 Batch  770/1077 - Train Accuracy: 0.9446, Validation Accuracy: 0.9439, Loss: 0.0274
# Epoch   2 Batch  780/1077 - Train Accuracy: 0.9590, Validation Accuracy: 0.9489, Loss: 0.0330
# Epoch   2 Batch  790/1077 - Train Accuracy: 0.9406, Validation Accuracy: 0.9482, Loss: 0.0314
# Epoch   2 Batch  800/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9517, Loss: 0.0289
# Epoch   2 Batch  810/1077 - Train Accuracy: 0.9747, Validation Accuracy: 0.9528, Loss: 0.0199
# Epoch   2 Batch  820/1077 - Train Accuracy: 0.9715, Validation Accuracy: 0.9467, Loss: 0.0255
# Epoch   2 Batch  830/1077 - Train Accuracy: 0.9320, Validation Accuracy: 0.9467, Loss: 0.0377
# Epoch   2 Batch  840/1077 - Train Accuracy: 0.9855, Validation Accuracy: 0.9439, Loss: 0.0242
# Epoch   2 Batch  850/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9432, Loss: 0.0435
# Epoch   2 Batch  860/1077 - Train Accuracy: 0.9706, Validation Accuracy: 0.9652, Loss: 0.0274
# Epoch   2 Batch  870/1077 - Train Accuracy: 0.9498, Validation Accuracy: 0.9503, Loss: 0.0277
# Epoch   2 Batch  880/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9606, Loss: 0.0342
# Epoch   2 Batch  890/1077 - Train Accuracy: 0.9587, Validation Accuracy: 0.9513, Loss: 0.0212
# Epoch   2 Batch  900/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9570, Loss: 0.0281
# Epoch   2 Batch  910/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9549, Loss: 0.0301
# Epoch   2 Batch  920/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9581, Loss: 0.0269
# Epoch   2 Batch  930/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9538, Loss: 0.0303
# Epoch   2 Batch  940/1077 - Train Accuracy: 0.9652, Validation Accuracy: 0.9659, Loss: 0.0237
# Epoch   2 Batch  950/1077 - Train Accuracy: 0.9710, Validation Accuracy: 0.9588, Loss: 0.0253
# Epoch   2 Batch  960/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9457, Loss: 0.0246
# Epoch   2 Batch  970/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9648, Loss: 0.0306
# Epoch   2 Batch  980/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.9638, Loss: 0.0233
# Epoch   2 Batch  990/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9528, Loss: 0.0288
# Epoch   2 Batch 1000/1077 - Train Accuracy: 0.9568, Validation Accuracy: 0.9602, Loss: 0.0277
# Epoch   2 Batch 1010/1077 - Train Accuracy: 0.9711, Validation Accuracy: 0.9570, Loss: 0.0187
# Epoch   2 Batch 1020/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9503, Loss: 0.0175
# Epoch   2 Batch 1030/1077 - Train Accuracy: 0.9656, Validation Accuracy: 0.9556, Loss: 0.0211
# Epoch   2 Batch 1040/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9496, Loss: 0.0269
# Epoch   2 Batch 1050/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9510, Loss: 0.0172
# Epoch   2 Batch 1060/1077 - Train Accuracy: 0.9750, Validation Accuracy: 0.9521, Loss: 0.0191
# Epoch   2 Batch 1070/1077 - Train Accuracy: 0.9750, Validation Accuracy: 0.9531, Loss: 0.0251
# Epoch   3 Batch   10/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.9677, Loss: 0.0227
# Epoch   3 Batch   20/1077 - Train Accuracy: 0.9648, Validation Accuracy: 0.9670, Loss: 0.0182
# Epoch   3 Batch   30/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9606, Loss: 0.0171
# Epoch   3 Batch   40/1077 - Train Accuracy: 0.9777, Validation Accuracy: 0.9545, Loss: 0.0183
# Epoch   3 Batch   50/1077 - Train Accuracy: 0.9684, Validation Accuracy: 0.9595, Loss: 0.0203
# Epoch   3 Batch   60/1077 - Train Accuracy: 0.9483, Validation Accuracy: 0.9535, Loss: 0.0204
# Epoch   3 Batch   70/1077 - Train Accuracy: 0.9638, Validation Accuracy: 0.9403, Loss: 0.0307
# Epoch   3 Batch   80/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9606, Loss: 0.0215
# Epoch   3 Batch   90/1077 - Train Accuracy: 0.9625, Validation Accuracy: 0.9563, Loss: 0.0234
# Epoch   3 Batch  100/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9528, Loss: 0.0184
# Epoch   3 Batch  110/1077 - Train Accuracy: 0.9715, Validation Accuracy: 0.9567, Loss: 0.0157
# Epoch   3 Batch  120/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9517, Loss: 0.0236
# Epoch   3 Batch  130/1077 - Train Accuracy: 0.9606, Validation Accuracy: 0.9673, Loss: 0.0225
# Epoch   3 Batch  140/1077 - Train Accuracy: 0.9749, Validation Accuracy: 0.9457, Loss: 0.0208
# Epoch   3 Batch  150/1077 - Train Accuracy: 0.9635, Validation Accuracy: 0.9648, Loss: 0.0215
# Epoch   3 Batch  160/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9613, Loss: 0.0173
# Epoch   3 Batch  170/1077 - Train Accuracy: 0.9543, Validation Accuracy: 0.9492, Loss: 0.0190
# Epoch   3 Batch  180/1077 - Train Accuracy: 0.9656, Validation Accuracy: 0.9577, Loss: 0.0193
# Epoch   3 Batch  190/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9489, Loss: 0.0149
# Epoch   3 Batch  200/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9645, Loss: 0.0252
# Epoch   3 Batch  210/1077 - Train Accuracy: 0.9661, Validation Accuracy: 0.9499, Loss: 0.0270
# Epoch   3 Batch  220/1077 - Train Accuracy: 0.9774, Validation Accuracy: 0.9741, Loss: 0.0263
# Epoch   3 Batch  230/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9457, Loss: 0.0194
# Epoch   3 Batch  240/1077 - Train Accuracy: 0.9898, Validation Accuracy: 0.9570, Loss: 0.0144
# Epoch   3 Batch  250/1077 - Train Accuracy: 0.9641, Validation Accuracy: 0.9609, Loss: 0.0220
# Epoch   3 Batch  260/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9648, Loss: 0.0166
# Epoch   3 Batch  270/1077 - Train Accuracy: 0.9746, Validation Accuracy: 0.9631, Loss: 0.0209
# Epoch   3 Batch  280/1077 - Train Accuracy: 0.9559, Validation Accuracy: 0.9521, Loss: 0.0233
# Epoch   3 Batch  290/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9489, Loss: 0.0268
# Epoch   3 Batch  300/1077 - Train Accuracy: 0.9803, Validation Accuracy: 0.9531, Loss: 0.0217
# Epoch   3 Batch  310/1077 - Train Accuracy: 0.9645, Validation Accuracy: 0.9574, Loss: 0.0245
# Epoch   3 Batch  320/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9453, Loss: 0.0280
# Epoch   3 Batch  330/1077 - Train Accuracy: 0.9602, Validation Accuracy: 0.9545, Loss: 0.0215
# Epoch   3 Batch  340/1077 - Train Accuracy: 0.9774, Validation Accuracy: 0.9549, Loss: 0.0233
# Epoch   3 Batch  350/1077 - Train Accuracy: 0.9781, Validation Accuracy: 0.9549, Loss: 0.0203
# Epoch   3 Batch  360/1077 - Train Accuracy: 0.9652, Validation Accuracy: 0.9560, Loss: 0.0168
# Epoch   3 Batch  370/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9471, Loss: 0.0231
# Epoch   3 Batch  380/1077 - Train Accuracy: 0.9812, Validation Accuracy: 0.9485, Loss: 0.0183
# Epoch   3 Batch  390/1077 - Train Accuracy: 0.9582, Validation Accuracy: 0.9620, Loss: 0.0269
# Epoch   3 Batch  400/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9599, Loss: 0.0270
# Epoch   3 Batch  410/1077 - Train Accuracy: 0.9511, Validation Accuracy: 0.9489, Loss: 0.0367
# Epoch   3 Batch  420/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9531, Loss: 0.0115
# Epoch   3 Batch  430/1077 - Train Accuracy: 0.9551, Validation Accuracy: 0.9471, Loss: 0.0201
# Epoch   3 Batch  440/1077 - Train Accuracy: 0.9590, Validation Accuracy: 0.9531, Loss: 0.0233
# Epoch   3 Batch  450/1077 - Train Accuracy: 0.9684, Validation Accuracy: 0.9627, Loss: 0.0234
# Epoch   3 Batch  460/1077 - Train Accuracy: 0.9566, Validation Accuracy: 0.9645, Loss: 0.0247
# Epoch   3 Batch  470/1077 - Train Accuracy: 0.9749, Validation Accuracy: 0.9606, Loss: 0.0176
# Epoch   3 Batch  480/1077 - Train Accuracy: 0.9716, Validation Accuracy: 0.9489, Loss: 0.0207
# Epoch   3 Batch  490/1077 - Train Accuracy: 0.9473, Validation Accuracy: 0.9524, Loss: 0.0227
# Epoch   3 Batch  500/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9595, Loss: 0.0193
# Epoch   3 Batch  510/1077 - Train Accuracy: 0.9543, Validation Accuracy: 0.9691, Loss: 0.0219
# Epoch   3 Batch  520/1077 - Train Accuracy: 0.9881, Validation Accuracy: 0.9531, Loss: 0.0124
# Epoch   3 Batch  530/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9595, Loss: 0.0257
# Epoch   3 Batch  540/1077 - Train Accuracy: 0.9652, Validation Accuracy: 0.9553, Loss: 0.0191
# Epoch   3 Batch  550/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9574, Loss: 0.0182
# Epoch   3 Batch  560/1077 - Train Accuracy: 0.9637, Validation Accuracy: 0.9585, Loss: 0.0220
# Epoch   3 Batch  570/1077 - Train Accuracy: 0.9593, Validation Accuracy: 0.9677, Loss: 0.0215
# Epoch   3 Batch  580/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9542, Loss: 0.0171
# Epoch   3 Batch  590/1077 - Train Accuracy: 0.9618, Validation Accuracy: 0.9545, Loss: 0.0236
# Epoch   3 Batch  600/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9585, Loss: 0.0245
# Epoch   3 Batch  610/1077 - Train Accuracy: 0.9667, Validation Accuracy: 0.9602, Loss: 0.0271
# Epoch   3 Batch  620/1077 - Train Accuracy: 0.9750, Validation Accuracy: 0.9648, Loss: 0.0213
# Epoch   3 Batch  630/1077 - Train Accuracy: 0.9711, Validation Accuracy: 0.9585, Loss: 0.0190
# Epoch   3 Batch  640/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9730, Loss: 0.0166
# Epoch   3 Batch  650/1077 - Train Accuracy: 0.9879, Validation Accuracy: 0.9712, Loss: 0.0150
# Epoch   3 Batch  660/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9691, Loss: 0.0150
# Epoch   3 Batch  670/1077 - Train Accuracy: 0.9787, Validation Accuracy: 0.9538, Loss: 0.0170
# Epoch   3 Batch  680/1077 - Train Accuracy: 0.9513, Validation Accuracy: 0.9585, Loss: 0.0227
# Epoch   3 Batch  690/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9528, Loss: 0.0232
# Epoch   3 Batch  700/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9492, Loss: 0.0165
# Epoch   3 Batch  710/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9709, Loss: 0.0124
# Epoch   3 Batch  720/1077 - Train Accuracy: 0.9700, Validation Accuracy: 0.9737, Loss: 0.0230
# Epoch   3 Batch  730/1077 - Train Accuracy: 0.9672, Validation Accuracy: 0.9616, Loss: 0.0260
# Epoch   3 Batch  740/1077 - Train Accuracy: 0.9430, Validation Accuracy: 0.9496, Loss: 0.0214
# Epoch   3 Batch  750/1077 - Train Accuracy: 0.9602, Validation Accuracy: 0.9656, Loss: 0.0212
# Epoch   3 Batch  760/1077 - Train Accuracy: 0.9730, Validation Accuracy: 0.9638, Loss: 0.0208
# Epoch   3 Batch  770/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9592, Loss: 0.0213
# Epoch   3 Batch  780/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.9535, Loss: 0.0245
# Epoch   3 Batch  790/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.9549, Loss: 0.0245
# Epoch   3 Batch  800/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9766, Loss: 0.0207
# Epoch   3 Batch  810/1077 - Train Accuracy: 0.9799, Validation Accuracy: 0.9673, Loss: 0.0136
# Epoch   3 Batch  820/1077 - Train Accuracy: 0.9758, Validation Accuracy: 0.9613, Loss: 0.0198
# Epoch   3 Batch  830/1077 - Train Accuracy: 0.9629, Validation Accuracy: 0.9680, Loss: 0.0267
# Epoch   3 Batch  840/1077 - Train Accuracy: 0.9668, Validation Accuracy: 0.9716, Loss: 0.0170
# Epoch   3 Batch  850/1077 - Train Accuracy: 0.9844, Validation Accuracy: 0.9577, Loss: 0.0295
# Epoch   3 Batch  860/1077 - Train Accuracy: 0.9661, Validation Accuracy: 0.9620, Loss: 0.0209
# Epoch   3 Batch  870/1077 - Train Accuracy: 0.9548, Validation Accuracy: 0.9510, Loss: 0.0205
# Epoch   3 Batch  880/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9684, Loss: 0.0256
# Epoch   3 Batch  890/1077 - Train Accuracy: 0.9617, Validation Accuracy: 0.9545, Loss: 0.0205
# Epoch   3 Batch  900/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9652, Loss: 0.0202
# Epoch   3 Batch  910/1077 - Train Accuracy: 0.9498, Validation Accuracy: 0.9624, Loss: 0.0183
# Epoch   3 Batch  920/1077 - Train Accuracy: 0.9711, Validation Accuracy: 0.9595, Loss: 0.0146
# Epoch   3 Batch  930/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9442, Loss: 0.0164
# Epoch   3 Batch  940/1077 - Train Accuracy: 0.9625, Validation Accuracy: 0.9673, Loss: 0.0184
# Epoch   3 Batch  950/1077 - Train Accuracy: 0.9684, Validation Accuracy: 0.9698, Loss: 0.0135
# Epoch   3 Batch  960/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9705, Loss: 0.0159
# Epoch   3 Batch  970/1077 - Train Accuracy: 0.9668, Validation Accuracy: 0.9560, Loss: 0.0220
# Epoch   3 Batch  980/1077 - Train Accuracy: 0.9664, Validation Accuracy: 0.9609, Loss: 0.0148
# Epoch   3 Batch  990/1077 - Train Accuracy: 0.9905, Validation Accuracy: 0.9638, Loss: 0.0177
# Epoch   3 Batch 1000/1077 - Train Accuracy: 0.9702, Validation Accuracy: 0.9602, Loss: 0.0177
# Epoch   3 Batch 1010/1077 - Train Accuracy: 0.9824, Validation Accuracy: 0.9524, Loss: 0.0151
# Epoch   3 Batch 1020/1077 - Train Accuracy: 0.9625, Validation Accuracy: 0.9556, Loss: 0.0173
# Epoch   3 Batch 1030/1077 - Train Accuracy: 0.9895, Validation Accuracy: 0.9624, Loss: 0.0147
# Epoch   3 Batch 1040/1077 - Train Accuracy: 0.9733, Validation Accuracy: 0.9581, Loss: 0.0208
# Epoch   3 Batch 1050/1077 - Train Accuracy: 0.9824, Validation Accuracy: 0.9567, Loss: 0.0124
# Epoch   3 Batch 1060/1077 - Train Accuracy: 0.9832, Validation Accuracy: 0.9521, Loss: 0.0162
# Epoch   3 Batch 1070/1077 - Train Accuracy: 0.9727, Validation Accuracy: 0.9517, Loss: 0.0214
# Epoch   4 Batch   10/1077 - Train Accuracy: 0.9794, Validation Accuracy: 0.9744, Loss: 0.0268
# Epoch   4 Batch   20/1077 - Train Accuracy: 0.9824, Validation Accuracy: 0.9648, Loss: 0.0165
# Epoch   4 Batch   30/1077 - Train Accuracy: 0.9852, Validation Accuracy: 0.9673, Loss: 0.0157
# Epoch   4 Batch   40/1077 - Train Accuracy: 0.9852, Validation Accuracy: 0.9748, Loss: 0.0191
# Epoch   4 Batch   50/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9631, Loss: 0.0204
# Epoch   4 Batch   60/1077 - Train Accuracy: 0.9810, Validation Accuracy: 0.9641, Loss: 0.0175
# Epoch   4 Batch   70/1077 - Train Accuracy: 0.9712, Validation Accuracy: 0.9556, Loss: 0.0208
# Epoch   4 Batch   80/1077 - Train Accuracy: 0.9703, Validation Accuracy: 0.9659, Loss: 0.0164
# Epoch   4 Batch   90/1077 - Train Accuracy: 0.9758, Validation Accuracy: 0.9705, Loss: 0.0165
# Epoch   4 Batch  100/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9702, Loss: 0.0120
# Epoch   4 Batch  110/1077 - Train Accuracy: 0.9852, Validation Accuracy: 0.9641, Loss: 0.0141
# Epoch   4 Batch  120/1077 - Train Accuracy: 0.9730, Validation Accuracy: 0.9680, Loss: 0.0185
# Epoch   4 Batch  130/1077 - Train Accuracy: 0.9606, Validation Accuracy: 0.9670, Loss: 0.0167
# Epoch   4 Batch  140/1077 - Train Accuracy: 0.9737, Validation Accuracy: 0.9620, Loss: 0.0221
# Epoch   4 Batch  150/1077 - Train Accuracy: 0.9743, Validation Accuracy: 0.9602, Loss: 0.0150
# Epoch   4 Batch  160/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9776, Loss: 0.0099
# Epoch   4 Batch  170/1077 - Train Accuracy: 0.9707, Validation Accuracy: 0.9517, Loss: 0.0166
# Epoch   4 Batch  180/1077 - Train Accuracy: 0.9746, Validation Accuracy: 0.9652, Loss: 0.0142
# Epoch   4 Batch  190/1077 - Train Accuracy: 0.9750, Validation Accuracy: 0.9666, Loss: 0.0135
# Epoch   4 Batch  200/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9709, Loss: 0.0185
# Epoch   4 Batch  210/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9624, Loss: 0.0175
# Epoch   4 Batch  220/1077 - Train Accuracy: 0.9860, Validation Accuracy: 0.9631, Loss: 0.0166
# Epoch   4 Batch  230/1077 - Train Accuracy: 0.9732, Validation Accuracy: 0.9659, Loss: 0.0161
# Epoch   4 Batch  240/1077 - Train Accuracy: 0.9898, Validation Accuracy: 0.9684, Loss: 0.0162
# Epoch   4 Batch  250/1077 - Train Accuracy: 0.9723, Validation Accuracy: 0.9645, Loss: 0.0175
# Epoch   4 Batch  260/1077 - Train Accuracy: 0.9565, Validation Accuracy: 0.9730, Loss: 0.0169
# Epoch   4 Batch  270/1077 - Train Accuracy: 0.9863, Validation Accuracy: 0.9648, Loss: 0.0163
# Epoch   4 Batch  280/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9684, Loss: 0.0201
# Epoch   4 Batch  290/1077 - Train Accuracy: 0.9727, Validation Accuracy: 0.9549, Loss: 0.0247
# Epoch   4 Batch  300/1077 - Train Accuracy: 0.9807, Validation Accuracy: 0.9638, Loss: 0.0160
# Epoch   4 Batch  310/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9677, Loss: 0.0207
# Epoch   4 Batch  320/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9634, Loss: 0.0199
# Epoch   4 Batch  330/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9521, Loss: 0.0158
# Epoch   4 Batch  340/1077 - Train Accuracy: 0.9827, Validation Accuracy: 0.9688, Loss: 0.0174
# Epoch   4 Batch  350/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9670, Loss: 0.0154
# Epoch   4 Batch  360/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9638, Loss: 0.0138
# Epoch   4 Batch  370/1077 - Train Accuracy: 0.9829, Validation Accuracy: 0.9684, Loss: 0.0153
# Epoch   4 Batch  380/1077 - Train Accuracy: 0.9785, Validation Accuracy: 0.9677, Loss: 0.0152
# Epoch   4 Batch  390/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9716, Loss: 0.0175
# Epoch   4 Batch  400/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9719, Loss: 0.0135
# Epoch   4 Batch  410/1077 - Train Accuracy: 0.9601, Validation Accuracy: 0.9599, Loss: 0.0250
# Epoch   4 Batch  420/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9592, Loss: 0.0096
# Epoch   4 Batch  430/1077 - Train Accuracy: 0.9832, Validation Accuracy: 0.9563, Loss: 0.0125
# Epoch   4 Batch  440/1077 - Train Accuracy: 0.9750, Validation Accuracy: 0.9634, Loss: 0.0141
# Epoch   4 Batch  450/1077 - Train Accuracy: 0.9711, Validation Accuracy: 0.9613, Loss: 0.0182
# Epoch   4 Batch  460/1077 - Train Accuracy: 0.9547, Validation Accuracy: 0.9663, Loss: 0.0164
# Epoch   4 Batch  470/1077 - Train Accuracy: 0.9881, Validation Accuracy: 0.9719, Loss: 0.0148
# Epoch   4 Batch  480/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9634, Loss: 0.0169
# Epoch   4 Batch  490/1077 - Train Accuracy: 0.9582, Validation Accuracy: 0.9652, Loss: 0.0191
# Epoch   4 Batch  500/1077 - Train Accuracy: 0.9793, Validation Accuracy: 0.9634, Loss: 0.0135
# Epoch   4 Batch  510/1077 - Train Accuracy: 0.9672, Validation Accuracy: 0.9666, Loss: 0.0175
# Epoch   4 Batch  520/1077 - Train Accuracy: 0.9885, Validation Accuracy: 0.9616, Loss: 0.0102
# Epoch   4 Batch  530/1077 - Train Accuracy: 0.9551, Validation Accuracy: 0.9759, Loss: 0.0211
# Epoch   4 Batch  540/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9627, Loss: 0.0131
# Epoch   4 Batch  550/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.9606, Loss: 0.0147
# Epoch   4 Batch  560/1077 - Train Accuracy: 0.9656, Validation Accuracy: 0.9609, Loss: 0.0173
# Epoch   4 Batch  570/1077 - Train Accuracy: 0.9823, Validation Accuracy: 0.9588, Loss: 0.0139
# Epoch   4 Batch  580/1077 - Train Accuracy: 0.9862, Validation Accuracy: 0.9645, Loss: 0.0147
# Epoch   4 Batch  590/1077 - Train Accuracy: 0.9581, Validation Accuracy: 0.9531, Loss: 0.0159
# Epoch   4 Batch  600/1077 - Train Accuracy: 0.9814, Validation Accuracy: 0.9691, Loss: 0.0149
# Epoch   4 Batch  610/1077 - Train Accuracy: 0.9790, Validation Accuracy: 0.9645, Loss: 0.0236
# Epoch   4 Batch  620/1077 - Train Accuracy: 0.9793, Validation Accuracy: 0.9705, Loss: 0.0206
# Epoch   4 Batch  630/1077 - Train Accuracy: 0.9855, Validation Accuracy: 0.9766, Loss: 0.0184
# Epoch   4 Batch  640/1077 - Train Accuracy: 0.9855, Validation Accuracy: 0.9748, Loss: 0.0139
# Epoch   4 Batch  650/1077 - Train Accuracy: 0.9934, Validation Accuracy: 0.9645, Loss: 0.0100
# Epoch   4 Batch  660/1077 - Train Accuracy: 0.9852, Validation Accuracy: 0.9616, Loss: 0.0130
# Epoch   4 Batch  670/1077 - Train Accuracy: 0.9822, Validation Accuracy: 0.9620, Loss: 0.0160
# Epoch   4 Batch  680/1077 - Train Accuracy: 0.9635, Validation Accuracy: 0.9645, Loss: 0.0159
# Epoch   4 Batch  690/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9606, Loss: 0.0189
# Epoch   4 Batch  700/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9766, Loss: 0.0100
# Epoch   4 Batch  710/1077 - Train Accuracy: 0.9930, Validation Accuracy: 0.9712, Loss: 0.0117
# Epoch   4 Batch  720/1077 - Train Accuracy: 0.9811, Validation Accuracy: 0.9606, Loss: 0.0218
# Epoch   4 Batch  730/1077 - Train Accuracy: 0.9656, Validation Accuracy: 0.9442, Loss: 0.0221
# Epoch   4 Batch  740/1077 - Train Accuracy: 0.9664, Validation Accuracy: 0.9570, Loss: 0.0147
# Epoch   4 Batch  750/1077 - Train Accuracy: 0.9746, Validation Accuracy: 0.9538, Loss: 0.0154
# Epoch   4 Batch  760/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9620, Loss: 0.0163
# Epoch   4 Batch  770/1077 - Train Accuracy: 0.9661, Validation Accuracy: 0.9510, Loss: 0.0146
# Epoch   4 Batch  780/1077 - Train Accuracy: 0.9730, Validation Accuracy: 0.9641, Loss: 0.0152
# Epoch   4 Batch  790/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9482, Loss: 0.0195
# Epoch   4 Batch  800/1077 - Train Accuracy: 0.9785, Validation Accuracy: 0.9634, Loss: 0.0146
# Epoch   4 Batch  810/1077 - Train Accuracy: 0.9896, Validation Accuracy: 0.9613, Loss: 0.0103
# Epoch   4 Batch  820/1077 - Train Accuracy: 0.9945, Validation Accuracy: 0.9680, Loss: 0.0110
# Epoch   4 Batch  830/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9616, Loss: 0.0257
# Epoch   4 Batch  840/1077 - Train Accuracy: 0.9934, Validation Accuracy: 0.9627, Loss: 0.0122
# Epoch   4 Batch  850/1077 - Train Accuracy: 0.9792, Validation Accuracy: 0.9648, Loss: 0.0260
# Epoch   4 Batch  860/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9780, Loss: 0.0156
# Epoch   4 Batch  870/1077 - Train Accuracy: 0.9585, Validation Accuracy: 0.9734, Loss: 0.0160
# Epoch   4 Batch  880/1077 - Train Accuracy: 0.9648, Validation Accuracy: 0.9535, Loss: 0.0213
# Epoch   4 Batch  890/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9773, Loss: 0.0149
# Epoch   4 Batch  900/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9673, Loss: 0.0172
# Epoch   4 Batch  910/1077 - Train Accuracy: 0.9669, Validation Accuracy: 0.9659, Loss: 0.0162
# Epoch   4 Batch  920/1077 - Train Accuracy: 0.9832, Validation Accuracy: 0.9670, Loss: 0.0121
# Epoch   4 Batch  930/1077 - Train Accuracy: 0.9875, Validation Accuracy: 0.9684, Loss: 0.0111
# Epoch   4 Batch  940/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9748, Loss: 0.0122
# Epoch   4 Batch  950/1077 - Train Accuracy: 0.9870, Validation Accuracy: 0.9705, Loss: 0.0078
# Epoch   4 Batch  960/1077 - Train Accuracy: 0.9866, Validation Accuracy: 0.9712, Loss: 0.0138
# Epoch   4 Batch  970/1077 - Train Accuracy: 0.9738, Validation Accuracy: 0.9616, Loss: 0.0164
# Epoch   4 Batch  980/1077 - Train Accuracy: 0.9789, Validation Accuracy: 0.9766, Loss: 0.0166
# Epoch   4 Batch  990/1077 - Train Accuracy: 0.9860, Validation Accuracy: 0.9695, Loss: 0.0152
# Epoch   4 Batch 1000/1077 - Train Accuracy: 0.9818, Validation Accuracy: 0.9680, Loss: 0.0177
# Epoch   4 Batch 1010/1077 - Train Accuracy: 0.9855, Validation Accuracy: 0.9496, Loss: 0.0121
# Epoch   4 Batch 1020/1077 - Train Accuracy: 0.9863, Validation Accuracy: 0.9553, Loss: 0.0125
# Epoch   4 Batch 1030/1077 - Train Accuracy: 0.9965, Validation Accuracy: 0.9648, Loss: 0.0114
# Epoch   4 Batch 1040/1077 - Train Accuracy: 0.9827, Validation Accuracy: 0.9588, Loss: 0.0191
# Epoch   4 Batch 1050/1077 - Train Accuracy: 0.9922, Validation Accuracy: 0.9609, Loss: 0.0102
# Epoch   4 Batch 1060/1077 - Train Accuracy: 0.9863, Validation Accuracy: 0.9663, Loss: 0.0127
# Epoch   4 Batch 1070/1077 - Train Accuracy: 0.9645, Validation Accuracy: 0.9616, Loss: 0.0136
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    return [vocab_to_int[w if w in vocab_to_int else '<UNK>'] for w in sentence.lower().split()]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [60, 74, 107, 77, 89, 143, 220]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [252, 132, 265, 14, 241, 77, 344, 348, 1]
#   French Words: il a vu un vieux camion jaune . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
